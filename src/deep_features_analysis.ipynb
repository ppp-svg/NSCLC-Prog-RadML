# %%
import pandas as pd
import numpy as np
import shap
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

from sklearn.model_selection import KFold, train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LassoCV

from lifelines import CoxPHFitter, KaplanMeierFitter
from lifelines.utils import concordance_index

from sksurv.ensemble import RandomSurvivalForest
from sksurv.ensemble import GradientBoostingSurvivalAnalysis
from sksurv.linear_model import CoxnetSurvivalAnalysis
from sksurv.metrics import concordance_index_censored, cumulative_dynamic_auc
from sksurv.util import Surv
from sklearn.feature_selection import VarianceThreshold
warnings.filterwarnings("ignore")

# %%
print("【加载数据】")
df_radiomics = pd.read_csv("deep_features.csv")
df_clinical = pd.read_csv("clinical_data.csv")
df_clinical = df_clinical[["PatientID", "Survival.time", "deadstatus.event"]]
df_merged = pd.merge(df_radiomics, df_clinical, on="PatientID")
print(f"合并后数据共 {len(df_merged)} 个样本")
print("数据预览：")
print(df_merged.head())

X = df_merged.drop(columns=['PatientID', 'Survival.time', 'deadstatus.event'])
y_time = df_merged['Survival.time']
y_event = df_merged['deadstatus.event'].astype(bool)
y = Surv.from_arrays(y_event, y_time)
# Out:
# 【加载数据】
# 合并后数据共 421 个样本
# 数据预览：
#    PatientID    feat_0    feat_1    feat_2    feat_3    feat_4    feat_5  \
# 0  LUNG1-001  0.180448 -0.284856  0.621785 -0.009765 -0.069112 -0.533970
# 1  LUNG1-002  0.217560 -0.144279  0.571718  0.077095 -0.062731 -0.482614
# 2  LUNG1-003 -0.020936  0.078977 -0.052550 -0.206237 -0.556817 -0.343911
# 3  LUNG1-004  0.228143 -0.108802  0.567799  0.338852 -0.017074 -0.524039
# 4  LUNG1-005  0.093502  0.129230  0.035716 -0.093134  0.000302 -0.584647
#
#      feat_6    feat_7    feat_8  ...  feat_760  feat_761  feat_762  feat_763  \
# 0  0.011818 -0.109398 -0.130200  ... -0.317042  0.163150  0.430214 -0.847012
# 1 -0.343305  0.067034 -0.408587  ... -0.018957  0.469836  0.459910 -1.022048
# 2 -0.096740 -0.452123 -0.201613  ... -0.445415 -0.142289  0.079599 -0.570729
# 3 -0.009116 -0.378448 -0.213142  ... -0.122894  0.047388  0.570875 -0.621193
# 4 -0.068624 -0.162298 -0.049244  ... -0.022158  0.254523  0.563861 -0.854975
#
#    feat_764  feat_765  feat_766  feat_767  Survival.time  deadstatus.event
# 0 -0.420224 -0.368981 -0.090759 -0.039002           2165                 1
# 1 -0.080495 -0.090473 -0.232029  0.092245            155                 1
# 2  0.143449 -0.295697 -0.120490  0.019754            256                 1
# 3 -0.215058 -0.030949 -0.208792 -0.047904            141                 1
# 4 -0.164612 -0.325791 -0.164704 -0.162702            353                 1
#
# [5 rows x 771 columns]

# %%
# 2. 预处理：缺失值填充与标准化
imputer = SimpleImputer(strategy="mean")
scaler = StandardScaler()
X = pd.DataFrame(imputer.fit_transform(X), columns=X.columns)
X = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)
#方差过滤
var_filter = VarianceThreshold(threshold=1e-3)
X_var = pd.DataFrame(var_filter.fit_transform(X), columns=X.columns[var_filter.get_support()])

# Lasso 拟合
lasso = LassoCV(cv=5, random_state=0).fit(X_var, y_time)
selected_features = X_var.columns[lasso.coef_ != 0]
X = X_var[selected_features]  # 注意更新的 X
print(X.shape)
# Out:
# (421, 11)

# %%
from sklearn.linear_model import lasso_path
import matplotlib.pyplot as plt
import numpy as np

# 计算 Lasso 路径
alphas_lasso, coefs_lasso, _ = lasso_path(X, y_time, alphas=None)

# 横坐标为 log10(alpha)
plt.figure(figsize=(12, 6))
log_alphas = np.log10(alphas_lasso)

# 只高亮最终被选中的特征，其它特征不加 label
for coef, feature in zip(coefs_lasso, X_var.columns):
        plt.plot(log_alphas, coef, label=feature, linewidth=2)

plt.xlabel("log10(alpha)")
plt.ylabel("Coefficient value")
plt.title("Lasso Coefficient Paths")
plt.axvline(np.log10(lasso.alpha_), color='red', linestyle='--', label=f'Selected alpha: {lasso.alpha_:.4f}')

# 设置图例排版（分多列）
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', ncol=1, fontsize='small')  # ✅ 可调节 ncol=2~3
plt.tight_layout(rect=[0, 0, 0.85, 1])  # ✅ 给右侧图例留空间
plt.savefig("lasso_coefficient_paths_compact.png", dpi=300)
plt.show()

# %%
# 5. 模型初始化
coxnet_model = CoxnetSurvivalAnalysis(l1_ratio=0.9, alpha_min_ratio=0.01, max_iter=10000)
rsf_model = RandomSurvivalForest(n_estimators=100, min_samples_split=10, min_samples_leaf=15, n_jobs=-1, random_state=0)
gbm_model = GradientBoostingSurvivalAnalysis(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=32)

models = {
    'Coxnet': coxnet_model,
    'RSF': rsf_model,
    'GBM': gbm_model
}

results = {}
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# %%
# 6. 交叉验证评估 C-index
for name, model in models.items():
    print(f"Training {name} model...")
    cindex_scores = []
    for train_idx, val_idx in kf.split(X):
        X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
        y_train, y_val = y[train_idx], y[val_idx]
        y_train_event = y_train['event']
        y_train_time = y_train['time']
        y_val_event = y_val['event']
        y_val_time = y_val['time']

        try:
            model.fit(X_train, y_train)
            pred_val = model.predict(X_val)
            c_index = concordance_index_censored(y_val_event, y_val_time, pred_val)[0]
        except Exception as e:
            print(f"{name} failed on fold due to: {e}")
            c_index = np.nan

        cindex_scores.append(c_index)
    results[name] = cindex_scores
print(results)
# Out:
# Training Coxnet model...
# Training RSF model...
# Training GBM model...
# {'Coxnet': [0.648905529953917, 0.6166960611405056, 0.5314302191464821, 0.6174516908212561, 0.638525564803805], 'RSF': [0.6682027649769585, 0.6169900058788947, 0.5605536332179931, 0.5884661835748792, 0.6230677764565993], 'GBM': [0.6483294930875576, 0.6225749559082893, 0.538638985005767, 0.5757850241545893, 0.616230677764566]}

# %%
import numpy as np
import pandas as pd

# 确保 results 是一个字典
if not isinstance(results, dict):
    raise TypeError(f"`results` 应该是字典，但你给的是 {type(results)}。请检查变量是否被覆盖。")

# 计算均值 ± 标准差，并保存为表格
summary = {
    "Model": [],
    "C-index (mean ± std)": []
}

for name, scores in results.items():
    mean = np.nanmean(scores)
    std = np.nanstd(scores)
    summary["Model"].append(name)
    summary["C-index (mean ± std)"].append(f"{mean:.3f} ± {std:.3f}")

summary_df = pd.DataFrame(summary)
summary_df.to_csv("cindex_summary.csv", index=False)

print("\nC-index summary saved to cindex_summary.csv")
print(summary_df)
# Out:
# C-index summary saved to cindex_summary.csv
#     Model C-index (mean ± std)
# 0  Coxnet        0.611 ± 0.041
# 1     RSF        0.611 ± 0.036
# 2     GBM        0.600 ± 0.039

# %%
print("Calculating SHAP values for GBSA...")
rsf_model.fit(X, y)
explainer = shap.Explainer(gbm_model.predict, X)
shap_values = explainer(X)
shap.summary_plot(shap_values, X, show=False)
plt.savefig("shap_summary_plot.png")
# Out:
# Calculating SHAP values for RSF...
# PermutationExplainer explainer:   1%|         | 4/421 [00:30<1:44:17, 15.01s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 4
#       2 rsf_model.fit(X, y)
#       3 explainer = shap.Explainer(rsf_model.predict, X)
# ----> 4 shap_values = explainer(X)
#       5 shap.summary_plot(shap_values, X, show=False)
#       6 plt.savefig("shap_summary_plot.png")
#
# File /opt/anaconda3/envs/dl/lib/python3.10/site-packages/shap/explainers/_permutation.py:100, in PermutationExplainer.__call__(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *args)
#      89 def __call__(
#      90     self,
#      91     *args,
#    (...)
#      97     silent=False,
#      98 ):
#      99     """Explain the output of the model on the given arguments."""
# --> 100     return super().__call__(
#     101         *args,
#     102         max_evals=max_evals,
#     103         main_effects=main_effects,
#     104         error_bounds=error_bounds,
#     105         batch_size=batch_size,
#     106         outputs=outputs,
#     107         silent=silent,
#     108     )
#
# File /opt/anaconda3/envs/dl/lib/python3.10/site-packages/shap/explainers/_explainer.py:366, in Explainer.__call__(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *args, **kwargs)
#     364     feature_names = [[] for _ in range(len(args))]
#     365 for row_args in show_progress(zip(*args), num_rows, self.__class__.__name__ + " explainer", silent):
# --> 366     row_result = self.explain_row(
#     367         *row_args,
#     368         max_evals=max_evals,
#     369         main_effects=main_effects,
#     370         error_bounds=error_bounds,
#     371         batch_size=batch_size,
#     372         outputs=outputs,
#     373         silent=silent,
#     374         **kwargs,
#     375     )
#     376     values.append(row_result.get("values", None))
#     377     output_indices.append(row_result.get("output_indices", None))
#
# File /opt/anaconda3/envs/dl/lib/python3.10/site-packages/shap/explainers/_permutation.py:162, in PermutationExplainer.explain_row(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *row_args)
#     159     i += 1
#     161 # evaluate the masked model
# --> 162 outputs = fm(masks, zero_index=0, batch_size=batch_size)
#     164 if row_values is None:
#     165     row_values = np.zeros((len(fm),) + outputs.shape[1:])
#
# File /opt/anaconda3/envs/dl/lib/python3.10/site-packages/shap/utils/_masked_model.py:57, in MaskedModel.__call__(self, masks, zero_index, batch_size)
#      55 if len(masks.shape) == 1:
#      56     if getattr(self.masker, "supports_delta_masking", False):
# ---> 57         return self._delta_masking_call(masks, zero_index=zero_index, batch_size=batch_size)
#      59     # we need to convert from delta masking to a full masking call because we were given a delta masking
#      60     # input but the masker does not support delta masking
#      61     else:
#      62         full_masks = np.zeros((int(np.sum(masks >= 0)), self._masker_cols), dtype=bool)
#
# File /opt/anaconda3/envs/dl/lib/python3.10/site-packages/shap/utils/_masked_model.py:209, in MaskedModel._delta_masking_call(self, masks, zero_index, batch_size)
#     206     batch_positions[i + 1] = batch_positions[i] + num_varying_rows[i]
#     208 # joined_masked_inputs = self._stack_inputs(all_masked_inputs)
# --> 209 outputs = self.model(*subset_masked_inputs)
#     210 _assert_output_input_match(subset_masked_inputs, outputs)
#     212 if self.linearize_link and self.link != links.identity and self._linearizing_weights is None:
#
# File /opt/anaconda3/envs/dl/lib/python3.10/site-packages/shap/models/_model.py:23, in Model.__call__(self, *args)
#      22 def __call__(self, *args):
# ---> 23     out = self.inner_model(*args)
#      24     is_tensor = safe_isinstance(out, "torch.Tensor")
#      25     out = out.cpu().detach().numpy() if is_tensor else np.array(out)
#
# File /opt/anaconda3/envs/dl/lib/python3.10/site-packages/sksurv/ensemble/forest.py:292, in _BaseSurvivalForest.predict(self, X)
#     268 def predict(self, X):
#     269     """Predict risk score.
#     270
#     271     The ensemble risk score is the total number of events,
#    (...)
#     290         Predicted risk scores.
#     291     """
# --> 292     return self._predict("predict", X)
#
# File /opt/anaconda3/envs/dl/lib/python3.10/site-packages/sksurv/ensemble/forest.py:260, in _BaseSurvivalForest._predict(self, predict_fn, X)
#     258 # Parallel loop
#     259 lock = threading.Lock()
# --> 260 Parallel(n_jobs=n_jobs, verbose=self.verbose, require="sharedmem")(
#     261     delayed(_accumulate_prediction)(_get_fn(e, predict_fn), X, [y_hat], lock) for e in self.estimators_
#     262 )
#     264 y_hat /= len(self.estimators_)
#     266 return y_hat
#
# File /opt/anaconda3/envs/dl/lib/python3.10/site-packages/joblib/parallel.py:2007, in Parallel.__call__(self, iterable)
#    2001 # The first item from the output is blank, but it makes the interpreter
#    2002 # progress until it enters the Try/Except block of the generator and
#    2003 # reaches the first `yield` statement. This starts the asynchronous
#    2004 # dispatch of the tasks to the workers.
#    2005 next(output)
# -> 2007 return output if self.return_generator else list(output)
#
# File /opt/anaconda3/envs/dl/lib/python3.10/site-packages/joblib/parallel.py:1650, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1647     yield
#    1649     with self._backend.retrieval_context():
# -> 1650         yield from self._retrieve()
#    1652 except GeneratorExit:
#    1653     # The generator has been garbage collected before being fully
#    1654     # consumed. This aborts the remaining tasks if possible and warn
#    1655     # the user if necessary.
#    1656     self._exception = True
#
# File /opt/anaconda3/envs/dl/lib/python3.10/site-packages/joblib/parallel.py:1762, in Parallel._retrieve(self)
#    1757 # If the next job is not ready for retrieval yet, we just wait for
#    1758 # async callbacks to progress.
#    1759 if ((len(self._jobs) == 0) or
#    1760     (self._jobs[0].get_status(
#    1761         timeout=self.timeout) == TASK_PENDING)):
# -> 1762     time.sleep(0.01)
#    1763     continue
#    1765 # We need to be careful: the job list can be filling up as
#    1766 # we empty it and Python list are not thread-safe by
#    1767 # default hence the use of the lock
#
# KeyboardInterrupt:

# %%
from lifelines import KaplanMeierFitter
from lifelines.statistics import logrank_test
import matplotlib.pyplot as plt
import numpy as np
import os

# 假设你已经训练好了三个模型：coxnet_model, rsf_model, coxph_model
# 并且有数据：X, y_time, y_event

models = {
    "Coxnet": coxnet_model,
    "RSF": rsf_model,
    "GBM": gbm_model
}

# 保存图像目录
os.makedirs("km_plots", exist_ok=True)

for model_name, model in models.items():
    print(f"Processing {model_name}...")

    # 获取模型预测（可以是风险分数或预测生存时间等）
    preds = model.predict(X)

    # 用中位数划分高低风险组
    median_pred = np.median(preds)
    risk_group = preds > median_pred

    # 拟合 KM 曲线
    fig, ax = plt.subplots(figsize=(8, 6))
    kmf = KaplanMeierFitter()

    kmf.fit(y_time[risk_group], event_observed=y_event[risk_group], label='High Risk')
    kmf.plot(ax=ax)

    kmf.fit(y_time[~risk_group], event_observed=y_event[~risk_group], label='Low Risk')
    kmf.plot(ax=ax)
    ax.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)

    # 计算 log-rank 检验的 p 值
    results = logrank_test(
        y_time[risk_group], y_time[~risk_group],
        event_observed_A=y_event[risk_group],
        event_observed_B=y_event[~risk_group]
    )
    p_value = results.p_value

    # 转换为科学计数法字符串（例如：1.23e-05）
    p_text = f"Log-rank p = {p_value:.1e}"

    # 在图的右上角写入 p 值
    plt.text(
        0.95, 0.7, p_text,
        horizontalalignment='right',
        verticalalignment='top',
        transform=ax.transAxes,
        fontsize=12,
        bbox=dict(facecolor='white', alpha=0.7, edgecolor='white')
    )

    # 设置图像标题和标签
    plt.title(f"{model_name} Kaplan-Meier Curve")
    plt.xlabel("Time")
    plt.ylabel("Survival Probability")
    plt.tight_layout()

    # 保存图像
    plt.savefig(f"km_plots/{model_name.lower()}_km_curve.png", dpi=300)
    plt.close()
# Out:
# Processing Coxnet...
# Processing RSF...
# Processing GBM...
